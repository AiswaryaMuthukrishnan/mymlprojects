# %% [markdown]
# <a href="https://colab.research.google.com/github/AiswaryaMuthukrishnan/mymlprojects/blob/main/VEGETABLE_CLASSIFIER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to ignore the warnings 
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/veggies.zip"
# Out:
# Archive:  /content/drive/MyDrive/veggies.zip
#    creating: vegetable/Potato/
#   inflating: vegetable/Potato/potato (1).jpg
#   inflating: vegetable/Potato/potato (10).jpg
#   inflating: vegetable/Potato/potato (100).jpg
#   inflating: vegetable/Potato/potato (1000).jpg
#   inflating: vegetable/Potato/potato (101).jpg
#   inflating: vegetable/Potato/potato (102).jpg
#   inflating: vegetable/Potato/potato (103).jpg
#   inflating: vegetable/Potato/potato (104).jpg
#   inflating: vegetable/Potato/potato (105).jpg
#   inflating: vegetable/Potato/potato (106).jpg
#   inflating: vegetable/Potato/potato (107).jpg
#   inflating: vegetable/Potato/potato (108).jpg
#   inflating: vegetable/Potato/potato (109).jpg
#   inflating: vegetable/Potato/potato (11).jpg
#   inflating: vegetable/Potato/potato (110).jpg
#   inflating: vegetable/Potato/potato (111).jpg
#   inflating: vegetable/Potato/potato (112).jpg
#   inflating: vegetable/Potato/potato (113).jpg
# ...

# %%
import pandas as pd
import numpy as np
import os
import shutil
import glob
import matplotlib.pyplot as plt

# %%
ROOT_DIR = "/content/vegetable"
imgs  =['potato','pumpkin','raddish','tomato']
NEW_DIR = "/content/all_images40/"

# %%
# Copy all my images to a new folder i.e NEW_DIR

if not os.path.exists(NEW_DIR):
  os.mkdir(NEW_DIR)

  for i in imgs:
    org_dir = os.path.join(ROOT_DIR, i+"/")
    
    for imgfile in glob.iglob(os.path.join(org_dir, "*.jpg")):
      shutil.copy(imgfile, NEW_DIR)
      
else:
  print("Already Exist")

# %%
#counter = {'potato':0,'pumpkin':0,'raddish':0,'tomato':0}

# %%
for image in imgs:
  print(image)
  # print(imgs)
  # print(NEW_DIR)
# Out:
# potato
# pumpkin
# raddish
# tomato

# %%
for image in imgs:
   print(NEW_DIR+image+"*")
# Out:
# /content/all_images40/potato*
# /content/all_images40/pumpkin*
# /content/all_images40/raddish*
# /content/all_images40/tomato*

# %%
counter = {'potato':0,'pumpkin':0,'raddish':0,'tomato':0}
for image in imgs:
  for count in glob.iglob(NEW_DIR+image+"*"):
    counter[image] += 1
    # print(count)

print(counter)
# Out:
# {'potato': 1000, 'pumpkin': 1000, 'raddish': 1000, 'tomato': 1000}

# %%
plt.figure(figsize=(10,5))
plt.bar(x = counter.keys(), height= counter.values())
plt.show()

# %%
#Creating the folder

if not os.path.exists(NEW_DIR+"train_test_split/"):

  os.makedirs(NEW_DIR+"train_test_split/")

  os.makedirs(NEW_DIR+"train_test_split/train/potato")
  os.makedirs(NEW_DIR+"train_test_split/train/pumpkin")
  os.makedirs(NEW_DIR+"train_test_split/train/raddish")
  os.makedirs(NEW_DIR+"train_test_split/train/tomato")
  
  os.makedirs(NEW_DIR+"train_test_split/test/potato")
  os.makedirs(NEW_DIR+"train_test_split/test/pumpkin")
  os.makedirs(NEW_DIR+"train_test_split/test/raddish")
  os.makedirs(NEW_DIR+"train_test_split/test/tomato")

  os.makedirs(NEW_DIR+"train_test_split/validation/potato")
  os.makedirs(NEW_DIR+"train_test_split/validation/pumpkin")
  os.makedirs(NEW_DIR+"train_test_split/validation/raddish")
  os.makedirs(NEW_DIR+"train_test_split/validation/tomato")

      
  # Train Data
  for i in np.random.choice(replace= False , size= 236 , a = glob.glob(NEW_DIR+imgs[0]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/train/potato" )
    os.remove(i)

  for i in np.random.choice(replace= False , size= 240 , a = glob.glob(NEW_DIR+imgs[1]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/train/pumpkin" )
    os.remove(i)

  for i in np.random.choice(replace= False , size= 260 , a = glob.glob(NEW_DIR+imgs[2]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/train/raddish" )
    os.remove(i)

  for i in np.random.choice(replace= False , size= 213 , a = glob.glob(NEW_DIR+imgs[3]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/train/tomato" )
    os.remove(i)



  # Validation Data
  for i in np.random.choice(replace= False , size= 29 , a = glob.glob(NEW_DIR+imgs[0]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/validation/potato" )
    os.remove(i)

  for i in np.random.choice(replace= False , size= 34 , a = glob.glob(NEW_DIR+imgs[1]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/validation/pumpkin" )
    os.remove(i)


  for i in np.random.choice(replace= False , size= 33 , a = glob.glob(NEW_DIR+imgs[2]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/validation/raddish" )
    os.remove(i)

  for i in np.random.choice(replace= False , size= 26 , a = glob.glob(NEW_DIR+imgs[3]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/validation/tomato" )
    os.remove(i)



  # Test Data
  for i in np.random.choice(replace= False , size= 30 , a = glob.glob(NEW_DIR+imgs[0]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/test/potato" )
    os.remove(i)
  
  for i in np.random.choice(replace= False , size= 30 , a = glob.glob(NEW_DIR+imgs[1]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/test/pumpkin" )
    os.remove(i)


  for i in np.random.choice(replace= False , size= 30 , a = glob.glob(NEW_DIR+imgs[2]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/test/raddish" )
    os.remove(i)

  for i in np.random.choice(replace= False , size= 27 , a = glob.glob(NEW_DIR+imgs[3]+"*") ):
    shutil.copy(i , NEW_DIR+"train_test_split/test/tomato" )
    os.remove(i)

# %%
train_path  = "/content/all_images40/train_test_split/train"
valid_path  = "/content/all_images40/train_test_split/validation"
test_path   = "/content/all_images40/train_test_split/test"
print("splited")
# Out:
# splited

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import vgg16
from keras.models import Model
from keras.layers import Dense, MaxPool2D, Conv2D
import keras

# %%
train_data_gen = ImageDataGenerator(preprocessing_function= vgg16.preprocess_input , zoom_range= 0.2, horizontal_flip= True, shear_range= 0.2 , rescale= 1./255)
train = train_data_gen.flow_from_directory(directory= train_path , target_size=(224,224))
# Out:
# Found 949 images belonging to 4 classes.

# %%
validation_data_gen = ImageDataGenerator(preprocessing_function= vgg16.preprocess_input , rescale= 1./255 )
valid = validation_data_gen.flow_from_directory(directory= valid_path , target_size=(224,224))
# Out:
# Found 122 images belonging to 4 classes.

# %%
test_data_gen = ImageDataGenerator(preprocessing_function= vgg16.preprocess_input, rescale= 1./255 )
test = train_data_gen.flow_from_directory(directory= test_path , target_size=(224,224), shuffle= False)
# Out:
# Found 117 images belonging to 4 classes.

# %%
train.class_indices
# Out:
# {'potato': 0, 'pumpkin': 1, 'raddish': 2, 'tomato': 3}

# %%
class_type = {0:'potato',  1 :'pumpkin', 2:'raddish', 3:'tomato'}

# %%
t_img , label = train.next()

# %%
def plotImages(img_arr, label):

  for im, l in zip(img_arr,label) :
    plt.figure(figsize= (5,5))
    plt.imshow(im, cmap = 'gray')
    plt.title(im.shape)
    plt.axis = False
    plt.show()

# %%
plotImages(t_img, label)

# %%
from keras.applications.vgg16 import VGG16
from keras.layers import Flatten , Dense, Dropout , MaxPool2D

# %%
from keras.applications.vgg16 import VGG16
from keras.layers import Flatten , Dense, Dropout , MaxPool2D

# %%
vgg = VGG16( input_shape=(224,224,3), include_top= False) # include_top will consider the new weights
# Out:
# ...
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
for layer in vgg.layers:           # Dont Train the parameters again 
  layer.trainable = False

# %%
x = Flatten()(vgg.output)
x = Dense(units=4, activation='softmax', name = 'predictions' )(x)

model = Model(vgg.input, x)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
model.compile(optimizer='adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
# implementing early stopping and model check point 

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

es = EarlyStopping(monitor= "val_accuracy" , min_delta= 0.01, patience= 3, verbose=1)
mc = ModelCheckpoint(filepath="bestmodel.h5", monitor="val_accuracy", verbose=1, save_best_only= False)

# %%
#hist = model.fit_generator(train, steps_per_epoch= 10, epochs= 8, validation_data= valid , validation_steps= 32)
hist = model.fit_generator(train, steps_per_epoch= 10, epochs=20 , validation_data= valid , validation_steps= 32, callbacks=[mc])
# Out:
# Epoch 1/20
# 10/10 [==============================] - ETA: 0s - loss: 1.2101 - accuracy: 0.5312
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 32 batches). You may need to use the repeat() function when building your dataset.
# Epoch 1: saving model to bestmodel.h5
# 10/10 [==============================] - 19s 989ms/step - loss: 1.2101 - accuracy: 0.5312 - val_loss: 0.3869 - val_accuracy: 0.8689
# Epoch 2/20
# 10/10 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.9191
# Epoch 2: saving model to bestmodel.h5
# 10/10 [==============================] - 7s 748ms/step - loss: 0.2731 - accuracy: 0.9191
# Epoch 3/20
# 10/10 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9656
# Epoch 3: saving model to bestmodel.h5
# 10/10 [==============================] - 5s 414ms/step - loss: 0.1200 - accuracy: 0.9656
# ...

# %%
## load only the best model 
from keras.models import load_model
model = load_model("bestmodel.h5")

# %%
h = hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# checking out the accuracy of our model 

acc = model.evaluate_generator(generator= test)[1] 

print(f"The accuracy of your model is = {acc} %")
# Out:
# The accuracy of your model is = 0.9829059839248657 %

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import load_img, img_to_array 

def get_img_array(img_path):
  """
  Input : Takes in image path as input 
  Output : Gives out Pre-Processed image
  """
  path = img_path
  img = image.load_img(path, target_size=(224,224,3))
  img = image.img_to_array(img)/255
  img = np.expand_dims(img , axis= 0 )
  
  return img

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/vegetable/potato/potato(1).jpg"       # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = class_type[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being potato is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being pumpkin is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being raddish is : {model.predict(img)[0][2]*100} percent")
print()
print(f"The chances of image being tomato is : {model.predict(img)[0][3]*100} percent")

# to display the image  
plt.imshow(img[0], cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 1s 896ms/step
# The given X-Ray image is of type = potato
#
# 1/1 [==============================] - 0s 21ms/step
# The chances of image being potato is : 95.11985778808594 percent
#
# 1/1 [==============================] - 0s 15ms/step
# The chances of image being pumpkin is : 0.1285885227844119 percent
#
# 1/1 [==============================] - 0s 16ms/step
# The chances of image being raddish is : 0.9102677926421165 percent
#
# 1/1 [==============================] - 0s 17ms/step
# The chances of image being tomato is : 3.8412917405366898 percent

# %% [markdown]
# /content/skindisease3/psoriasis/psoriasis_(10).jpg

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/vegetable/pumpkin/pumpkin (1).jpg"       # you can add any image path"   

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = class_type[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being potato is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being pumpkin is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being raddish is : {model.predict(img)[0][2]*100} percent")
print()
print(f"The chances of image being tomato is : {model.predict(img)[0][3]*100} percent")

# to display the image  
plt.imshow(img[0], cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step
# The given X-Ray image is of type = pumpkin
#
# 1/1 [==============================] - 0s 15ms/step
# The chances of image being potato is : 11.531184613704681 percent
#
# 1/1 [==============================] - 0s 15ms/step
# The chances of image being pumpkin is : 87.95633912086487 percent
#
# 1/1 [==============================] - 0s 19ms/step
# The chances of image being raddish is : 0.08306138915941119 percent
#
# 1/1 [==============================] - 0s 18ms/step
# The chances of image being tomato is : 0.4294091835618019 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/vegetable/raddish/raddish (104).jpg"       # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = class_type[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being potato is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being pumpkin is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being raddish is : {model.predict(img)[0][2]*100} percent")
print()
print(f"The chances of image being tomato is : {model.predict(img)[0][3]*100} percent")

# to display the image  
plt.imshow(img[0], cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# The given X-Ray image is of type = raddish
#
# 1/1 [==============================] - 0s 19ms/step
# The chances of image being potato is : 0.00011359682048350805 percent
#
# 1/1 [==============================] - 0s 16ms/step
# The chances of image being pumpkin is : 0.005345457975636236 percent
#
# 1/1 [==============================] - 0s 17ms/step
# The chances of image being raddish is : 99.92976188659668 percent
#
# 1/1 [==============================] - 0s 16ms/step
# The chances of image being tomato is : 0.06477754795923829 percent

# %%
# path for that new image. ( you can take it either from google or any other scource)

path = "/content/vegetable/tomato/tomato (1).jpg"       # you can add any image path

#predictions: path:- provide any image from google or provide image from all image folder
img = get_img_array(path)

res = class_type[np.argmax(model.predict(img))]
print(f"The given X-Ray image is of type = {res}")
print()
print(f"The chances of image being potato is : {model.predict(img)[0][0]*100} percent")
print()
print(f"The chances of image being pumpkin is : {model.predict(img)[0][1]*100} percent")
print()
print(f"The chances of image being raddish is : {model.predict(img)[0][2]*100} percent")
print()
print(f"The chances of image being tomato is : {model.predict(img)[0][3]*100} percent")

# to display the image  
plt.imshow(img[0], cmap = "gray")
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# The given X-Ray image is of type = tomato
#
# 1/1 [==============================] - 0s 17ms/step
# The chances of image being potato is : 1.4229841530323029 percent
#
# 1/1 [==============================] - 0s 15ms/step
# The chances of image being pumpkin is : 0.05179861909709871 percent
#
# 1/1 [==============================] - 0s 17ms/step
# The chances of image being raddish is : 0.0761123956181109 percent
#
# 1/1 [==============================] - 0s 17ms/step
# The chances of image being tomato is : 98.44910502433777 percent

# %%
# this function is udes to generate the heat map of aan image
import tensorflow as tf

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
import matplotlib.cm as cm

from IPython.display import Image, display

# %%
# put the heatmap to our image to understand the area of interest
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import load_img, img_to_array 

def save_and_display_gradcam(img_path , heatmap, cam_path="cam.jpg", alpha=0.4):
    """
    img input shoud not be expanded 
    """

    # Load the original image
    img = image.load_img(img_path)
    img = image.img_to_array(img)

    
    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = image.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))

# %%
# function that is used to predict the image type and the ares that are affected by skin disease


def image_prediction_and_visualization(path,last_conv_layer_name = "block5_conv3", model = model):
  """
  input:  is the image path, name of last convolution layer , model name
  output : returs the predictions and the area that is effected
  """
  
  
  
  img_array = get_img_array(path)

  heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

  img = get_img_array(path)

  res = class_type[np.argmax(model.predict(img))]
  print(f"The given X-Ray image is of type = {res}")
  print()
  print(f"The chances of image being potato is : {model.predict(img)[0][0]*100} %")
  print(f"The chances of image being pumpkin is : {model.predict(img)[0][1]*100} %")
  print(f"The chances of image being raddish is : {model.predict(img)[0][2]*100} %")
  print(f"The chances of image being tomato is : {model.predict(img)[0][3]*100} %")


  print()
  print("image with heatmap representing the Vegetables")

  # function call
  save_and_display_gradcam(path, heatmap)

  print()
  print("the original input image")
  print()

  a = plt.imread(path)
  plt.imshow(a, cmap = "gray")
  plt.title("Original image")
  plt.show()

# %%
#predictions
# provide the path of any image from google or any other scource 
# the path is already defigned above , but you can also provide the path here to avoid scrolling up 

# for covid image : 
path ="/content/vegetable/tomato/tomato (1).jpg"

image_prediction_and_visualization(path)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# The given X-Ray image is of type = tomato
#
# 1/1 [==============================] - 0s 15ms/step
# The chances of image being potato is : 1.4229841530323029 %
# 1/1 [==============================] - 0s 19ms/step
# The chances of image being pumpkin is : 0.05179861909709871 %
# 1/1 [==============================] - 0s 15ms/step
# The chances of image being raddish is : 0.0761123956181109 %
# 1/1 [==============================] - 0s 17ms/step
# The chances of image being tomato is : 98.44910502433777 %
#
# image with heatmap representing the Vegetables
# the original input image

# %%
#predictions
# provide the path of any image from google or any other scource 
# the path is already defigned above , but you can also provide the path here to avoid scrolling up 

# for covid image : 
path = "/content/vegetable/potato/potato (839).jpg"

image_prediction_and_visualization(path)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# The given X-Ray image is of type = potato
#
# 1/1 [==============================] - 0s 17ms/step
# The chances of image being potato is : 95.2568769454956 %
# 1/1 [==============================] - 0s 15ms/step
# The chances of image being pumpkin is : 0.037017965223640203 %
# 1/1 [==============================] - 0s 16ms/step
# The chances of image being raddish is : 3.441128134727478 %
# 1/1 [==============================] - 0s 16ms/step
# The chances of image being tomato is : 1.2649801559746265 %
#
# image with heatmap representing the Vegetables
# the original input image
